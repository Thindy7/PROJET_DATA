# %% [markdown]
# DESCRIPTION
#
# Un ETL (Extract - Transform - Load ) est un processus qui permet de collecter les données de plusieurs sources, d’y effectuer des transformations et de les charger dans un data warehouse, une base de données, un datalake ou autre… L’intérêt de la mise en place de tel système est  donc de centraliser et consolider les données un seul référentiel fiable utile pour des analyses permettant de faciliter la prise de décisions.
# Dans ce challenge, votre objectif est d'utiliser les techniques et outils de data engineering pour construire un ETL qui permettrait de collecter, traiter et stocker les articles_obam_obam issue de la plateforme du média américain The New York Times.
# L’objectif pour nous, est de trouver le meilleur candidat pour le l’offre de stage Génération automatique d’analyses économiques et financières et non d’avoir le meilleur ETL. Pour cela, nous évaluons la capacité des candidats à aborder un problème de data engineering assez complexe.
#
# Plusieurs axes de notation sont pris en compte pour l’évaluation de votre travail. Il s’agit de:
# la méthodologie de travail;
# la qualité du code;
# l’environnement de travail;
# la rigueur et la logique du travail.
#
# CONSIGNES
# Le travail à faire consiste en la mise en place d’un ETL.
# La source de données est l’API du média The New York Times.
# La fréquence de récupération des données est quotidienne (exemple: 0 8 * * *)
# Le stockage final est votre système de fichier. Vous devrez mettre en place une arborescence logique en fonction de la date des articles_obam_obam récupérés.
# L’étape de transformation consistera à
# Nettoyer les articles;
# Enrichir les articles avec un modèle d’analyse de sentiment
# NB: Python est le langage de programmation requis pour la réalisation de ce projet.
# Exemple d’outils utiles: Airflow, pylint, git, pandas, …
#
# LIVRABLE
# Le livrable que vous devez nous soumettre est l’url du repo github du projet que vous aurez pris le soins de bien documenter.
# DEADLINE
#
# Le projet doit être soumis au plus tard le 28 février 2023 à 23:59 GMT.

# %% [markdown]
# # MISE EN PLACE D'UN EXTRACT - TRANSFORM - LOAD (ETL)

# %%
# %pip install textBlob
# %pip install pynytimes
# %pip install nytimesarticle
# Out:
# Requirement already satisfied: textBlob in c:\users\nhoura\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\nhoura\anaconda3\lib\site-packages (from textBlob) (3.7)
# Requirement already satisfied: tqdm in c:\users\nhoura\anaconda3\lib\site-packages (from nltk>=3.1->textBlob) (4.64.1)
# Requirement already satisfied: joblib in c:\users\nhoura\anaconda3\lib\site-packages (from nltk>=3.1->textBlob) (1.1.1)
# Requirement already satisfied: click in c:\users\nhoura\anaconda3\lib\site-packages (from nltk>=3.1->textBlob) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nhoura\anaconda3\lib\site-packages (from nltk>=3.1->textBlob) (2022.7.9)
# Requirement already satisfied: colorama in c:\users\nhoura\anaconda3\lib\site-packages (from click->nltk>=3.1->textBlob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pynytimes in c:\users\nhoura\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.10.0 in c:\users\nhoura\anaconda3\lib\site-packages (from pynytimes) (2.28.1)
# Requirement already satisfied: urllib3 in c:\users\nhoura\anaconda3\lib\site-packages (from pynytimes) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nhoura\anaconda3\lib\site-packages (from requests<3.0.0,>=2.10.0->pynytimes) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nhoura\anaconda3\lib\site-packages (from requests<3.0.0,>=2.10.0->pynytimes) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nhoura\anaconda3\lib\site-packages (from requests<3.0.0,>=2.10.0->pynytimes) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nytimesarticle in c:\users\nhoura\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: requests>=2.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from nytimesarticle) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nhoura\anaconda3\lib\site-packages (from requests>=2.1.0->nytimesarticle) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nhoura\anaconda3\lib\site-packages (from requests>=2.1.0->nytimesarticle) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nhoura\anaconda3\lib\site-packages (from requests>=2.1.0->nytimesarticle) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nhoura\anaconda3\lib\site-packages (from requests>=2.1.0->nytimesarticle) (1.26.12)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # EXTRACT

# %%
# Api du media The New York Times

import requests
import pandas as pd
import nltk
from textblob import TextBlob
import os
from datetime import datetime, timedelta

# %%
# requête pour récupérer les articles du New York Times

#librairie pour récupérer les articles du New York Times
from nytimesarticle import articleAPI
from datetime import datetime, timedelta

def get_request(api_key, query, begin_date, end_date):
    begin_date_str = "" # exemple de chaîne de caractères pour une date de début
    end_date_str = "" # exemple de chaîne de caractères pour une date de fin

    begin_date = datetime.strptime("20230217", "%Y%m%d").date()
    end_date = datetime.strptime("20230227", "%Y%m%d").date()   

    article_obam = requests.get(api_key, query)
    if article_obam.status_code == 200:
        return article_obam.json()
    else:
        print(f"Error: {article_obam.status_code}")
        return None

# %%
# requête pour récupérer les articles du New York Times
from pynytimes import NYTAPI

key = "eujZVG99yNWDCAneFIsuUlxMZIbSAvwF"
def get_extract(key):
    nyt = NYTAPI(key)
    begin_date_str = "20220101" # exemple de chaîne de caractères pour une date de début
    end_date_str = "20220201" # exemple de chaîne de caractères pour une date de fin

    begin_date = datetime.strptime(begin_date_str, "%Y%m%d").date() # conversion de la chaîne de caractères en objet date
    end_date = datetime.strptime(end_date_str, "%Y%m%d").date() # conversion de la chaîne de caractères en objet date

    articles_obam = nyt.article_search(
        query="Obama",
        dates={"begin": begin_date, "end": end_date},
        results=43,
        options={"sort": "newest"}
    )
    return articles_obam

# %%
articles_obam = get_extract(key)

# %%
# Affichage des articles_obam

for article in articles_obam:
    print(article["headline"]["main"])
    print(article["snippet"])
    print(article["web_url"])
    print()
# Out:
# Spotify Backs Joe Rogan’s Disinformation Machine
# The streaming service picks Joe Rogan over Neil Young and Joni Mitchell.
# https://www.nytimes.com/2022/02/01/opinion/spotify-joe-rogan-disinformation.html
#
# A Race to Rethink Care After a Dire Diagnosis
# With the backing of venture capital and well-known tech investors, Synapticure seeks to fill in the gaps in care and research for those with amyotrophic lateral sclerosis.
# https://www.nytimes.com/2022/02/01/business/als-synapticure-startup.html
#
# Transcript: Ezra Klein Interviews Amanda Litman
# A conversation with the co-founder of Run for Something
# https://www.nytimes.com/2022/02/01/podcasts/transcript-ezra-klein-interviews-amanda-litman.html
#
# States Are Complicating Corporate Pandemic Planning
# Companies are wrestling with an array of state rules that makes designing pandemic policies tricky.
# https://www.nytimes.com/2022/02/01/business/dealbook/florida-texas-vaccine-mandates.html
#
# U.S. and Allies Close to Reviving Nuclear Deal With Iran, Officials Say
# A return to a 2015 accord is on the table, but the next decisions are up to the new government in Tehran, the Biden administration says.
# https://www.nytimes.com/2022/01/31/us/politics/iran-nuclear-deal-biden.html
#
# DeSantis and the Media: (Not) a Love Story
# The Florida governor and the mainstream press have had a rocky relationship that he has often worked to his advantage.
# https://www.nytimes.com/2022/01/31/us/politics/desantis-media.html
#
# The White House threatens sanctions against Putin’s ‘inner circle’ if Russia invades Ukraine.
# The Biden administration said the penalties would exceed any levied recently against Russia. It is unclear whether the list of targets includes Vladimir V. Putin himself.
# https://www.nytimes.com/2022/01/31/world/europe/putin-sanctions-list.html
#
# What a Disconnect From Swift Would Mean for Russia
# A Belgian financial messaging service is once again at the center of an international sanctions fight.
# https://www.nytimes.com/2022/01/31/us/politics/russia-swift.html
#
# Biden Administration to Reinstate Mercury Pollution Rules Weakened Under Trump
# The E.P.A. will resume enforcing limits on the release of mercury, a neurotoxin linked to developmental damage in children, from coal-burning power plants.
# https://www.nytimes.com/2022/01/31/climate/epa-mercury-pollution-coal.html
#
# Nothing’s More Fun Than Picking the Next Supreme Court Justice. Right?
# Sometimes fulfilling a campaign promise gets tricky.
# https://www.nytimes.com/2022/01/31/opinion/supreme-court-justice.html
#
# For Ketanji Brown Jackson, View of Criminal Justice Was Shaped by Family
# The story of an uncle’s cocaine conviction formed only part of Judge Jackson’s understanding of the system’s complexities. She is now seen as a contender to be President Biden’s Supreme Court pick.
# https://www.nytimes.com/2022/01/30/us/politics/supreme-court-ketanji-brown-jackson.html
#
# Black Women in Law Feel Pride and Frustration Ahead of Court Nominee
# As Biden prepares to nominate the first Black woman to the nation’s highest court, members of this small, elite group are watching with complicated emotions.
# https://www.nytimes.com/2022/01/29/us/supreme-court-black-women-biden.html
#
# U.S. Sanctions Aimed at Russia Could Take a Wide Toll
# The boldest measures that President Biden is threatening to deter an invasion of Ukraine could roil the entire Russian economy — but also those of other nations.
# https://www.nytimes.com/2022/01/29/us/politics/russia-sanctions-economy.html
#
# As Breyer Pondered Retirement, Biden Bet on a Hands-Off Strategy
# The president believed pressuring the court’s oldest justice to retire might backfire. A chorus of liberals took a different approach.
# https://www.nytimes.com/2022/01/28/us/politics/biden-breyer-retirement.html
#
# Democrats Should Take a Page From Mitch McConnell’s Book
# The deliberative process that our team followed with Obama’s nominees is outdated. Democrats should move as quickly as possible.
# https://www.nytimes.com/2022/01/28/opinion/politics/supreme-court-justice-democrat.html
#
# Chita Rivera’s Book Will Introduce Fans to the Real Her
# The Broadway star is writing a memoir with the help of a journalist who encouraged her to share what she’s really like, alter ego and all.
# https://www.nytimes.com/2022/01/28/arts/chita-rivera-book.html
#
# How Independent Voters Feel About Biden
# Responses to a focus group of independent voters. Also: President Biden and the economy; Boris Johnson; sanctions against Russia; debtors and lawyers.
# https://www.nytimes.com/2022/01/28/opinion/letters/independent-voters-biden.html
#
# The Battle for the World’s Most Powerful Cyberweapon
# A Times investigation reveals how Israel reaped diplomatic gains around the world from NSO’s Pegasus spyware — a tool America itself purchased but is now trying to ban.
# https://www.nytimes.com/2022/01/28/magazine/nso-group-israel-spyware.html
#
# The New York Times News Quiz, January 28, 2022
# Did you follow the news this week? Take our quiz to see how well you stack up with other Times readers.
# https://www.nytimes.com/interactive/2022/01/28/briefing/news-quiz-breyer-ukraine-jeopardy.html
#
# In Standoff With Putin, Biden Makes Sure European Allies Are With Him
# In what amounts to a much-needed diplomatic reset, the U.S. is orchestrating the response to Russia’s threatening moves and making sure to include his European allies.
# https://www.nytimes.com/2022/01/28/world/europe/biden-putin-ukraine-europe.html
#
# Growth Is Surging in Biden’s Economy. Why Don’t Voters Feel Better?
# President Biden is suffering in the polls as high inflation saps confidence in the economy, even as growth comes in strong.
# https://www.nytimes.com/2022/01/27/business/economy/biden-economy-politics.html
#
# Rabbi Israel Dresner, Civil Rights Champion and King Ally, Dies at 92
# He was jailed multiple times in the South during the 1960s and made human rights his lifelong cause, following the Jewish doctrine of “tikkun olam” — to repair the world.
# https://www.nytimes.com/2022/01/27/us/rabbi-israel-dresner-dead.html
#
# Biden plans to name Breyer’s successor by the end of February.
# Speaking with Justice Stephen Breyer by his side, Mr. Biden hailed his decades on the federal bench, including almost 28 years on the Supreme Court.
# https://www.nytimes.com/2022/01/27/us/politics/biden-breyer-retire.html
#
# After Breyer
# The latest on the coming Supreme Court nomination.
# https://www.nytimes.com/2022/01/27/briefing/stephen-breyer-retirement-biden-nomination.html
#
# U.S. Economy Grew 1.7% in 4th Quarter, Capping a Strong Year
# The overall 2021 increase in the gross domestic product was the biggest in decades as the pandemic’s effects eased, though challenges persist.
# https://www.nytimes.com/2022/01/27/business/us-gdp-4q-2021.html
#
# Can Biden Avert a Crisis With North Korea?
# Kim Jong-un, the North Korean leader, has done six missile tests this month — equal to all of 2021 — and called on the nation to prepare for “long-term confrontation.”
# https://www.nytimes.com/2022/01/27/us/politics/north-korea-biden-missile-tests.html
#
# Senate Democrats Plan to Move Quickly on Successor to Justice Breyer
# Given their tenuous majority, Democrats intend to act fast, anticipating roadblocks from Senator Mitch McConnell and Republicans.
# https://www.nytimes.com/2022/01/26/us/politics/senate-democrats-breyer-vacancy.html
#
# Breyer’s Retirement Gives Democrats a Dose of (Cautious) Optimism
# After a series of legislative losses, the chance for President Biden to fulfill a promise by nominating a Black woman was seen by progressives as a chance to show he could still bring about change.
# https://www.nytimes.com/2022/01/26/us/politics/democrats-stephen-breyer-retirement.html
#
# Here’s why Republicans can’t filibuster President Biden’s Supreme Court nominee.
# Though Democrats do not need to worry about Republicans using a filibuster against the forthcoming nominee, winning confirmation is no slam dunk.
# https://www.nytimes.com/2022/01/26/us/politics/biden-scotus-nominee-filibuster.html
#
# Justice Leondra R. Kruger of the California Supreme Court is a possible nominee.
# At 45, she would be younger than all but one of the current justices were when they were nominated.
# https://www.nytimes.com/2022/01/26/us/politics/justice-leondra-r-kruger.html
#
# The U.S.-Kurd alliance in Syria has a tangled history.
# American and Kurdish-led forces once beat back the Islamic State in Syria. Now they are fighting together again.
# https://www.nytimes.com/2022/01/26/world/middleeast/us-kurds-syria.html
#
# Biden Administration Cancels Mining Leases Near Wilderness Area
# The leases, reinstated during the Trump years, would have allowed a Chilean mining conglomerate to dig for copper and nickel near the Boundary Waters wilderness in Minnesota.
# https://www.nytimes.com/2022/01/26/climate/boundary-waters-copper-mining.html
#
# A top Biden ally has a favored candidate to replace Justice Breyer: Judge J. Michelle Childs.
# Representative James E. Clyburn, Democrat of South Carolina, supports a little-known federal judge in his home state: J. Michelle Childs.
# https://www.nytimes.com/2022/01/26/us/politics/j-michelle-childs.html
#
# Judge Ketanji Brown Jackson is among the leading candidates to succeed Justice Breyer.
# Judge Jackson, 51, already successfully went through the Senate confirmation process last year.
# https://www.nytimes.com/2022/01/26/us/politics/ketanji-brown-jackson-supreme-court.html
#
# Democrats can seat a new justice on their own, even if Republicans unite in opposition.
# Recent changes in Senate rules mean a nominee can be confirmed with a bare majority, but Democrats will have to hold their narrow ranks together.
# https://www.nytimes.com/2022/01/26/us/politics/supreme-court-nominee-nomination-biden-democrats.html
#
# Justice Breyer to Retire From Supreme Court
# The decision gives President Biden a window to fulfill a campaign pledge to nominate a Black woman to the court.
# https://www.nytimes.com/2022/01/26/us/stephen-breyer-retire-supreme-court.html
#
# A Surge at Sea: Migrants Seek Entry to the U.S. Aboard Flimsy Boats
# Coast Guard officials said a search was still underway for 38 migrants missing after a boat capsized off Florida. The situation looked increasingly dire.
# https://www.nytimes.com/2022/01/26/us/capsized-boat-florida.html
#
# Three New Faces to Help Steer the Gates Foundation
# In the wake of Bill Gates and Melinda French Gates’s divorce, their foundation added members to its new governing board.
# https://www.nytimes.com/2022/01/26/business/gates-foundation-new-trustees.html
#
# Confessions of a Liberal Heretic
# Ruy Teixeira was co-author of one of the most influential political books of the 21st century. Now, he says, Democrats are getting its lessons all wrong.
# https://www.nytimes.com/2022/01/25/us/politics/ruy-teixeira-democrats.html
#
# What Happens if Russia Cuts Off Europe’s Natural Gas?
# Europe is a huge customer of Russia’s fossil fuels. Gas from the U.S. and elsewhere is helping offset fears of a midwinter cutoff.
# https://www.nytimes.com/2022/01/25/business/energy-environment/russia-europe-natural-gas-ukraine.html
#
# They Need Legal Advice on Debts. Should It Have to Come From Lawyers?
# A nonprofit has filed a lawsuit in New York, hoping to clear the way for volunteers to help people defend themselves against debt collection suits.
# https://www.nytimes.com/2022/01/25/nyregion/consumer-debt-legal-advice.html
#
# Two Covid Americas
# The unvaccinated are less worried than the boosted, according to a poll.
# https://www.nytimes.com/2022/01/25/briefing/covid-behavior-vaccinated-unvaccinated.html
#
# Court Throws Out Alabama’s New Congressional Map
# A federal panel of judges ordered state lawmakers to redraw the lines, saying Black voters “have less opportunity than other Alabamians” to elect candidates of their choice.
# https://www.nytimes.com/2022/01/24/us/politics/alabama-congressional-map-redistricting.html
#
# Caught on a Hot Mic: Biden Uses a Vulgarity to Insult a Fox News Reporter
# The president later called Peter Doocy and “cleared the air,” Mr. Doocy said.
# https://www.nytimes.com/2022/01/24/business/media/biden-peter-doocy-fox.html
#
# We Used to Care That Football Players Got Concussions
# We seem to have lost our faith that we can make things better.
# https://www.nytimes.com/2022/01/24/opinion/football-players-concussions.html
#
# Donna Barba Higuera Wins Newbery Medal for ‘The Last Cuentista’
# “Watercress,” illustrated by Jason Chin and written by Andrea Wang, won the Caldecott Medal.
# https://www.nytimes.com/2022/01/24/books/newbery-last-cuentista-caldecott-watercress.html
#
# Omicron’s Economic Toll: Missing Workers, More Uncertainty and Higher Inflation (Maybe)
# The latest wave of coronavirus cases is slowing the recovery, but its longer-term impact is less clear.
# https://www.nytimes.com/2022/01/24/business/economy/omicron-economy.html
#
# Supreme Court Will Hear Challenge to Affirmative Action at Harvard and U.N.C.
# The court’s new conservative supermajority may be skeptical of admissions programs that take account of race to foster educational diversity.
# https://www.nytimes.com/2022/01/24/us/politics/supreme-court-affirmative-action-harvard-unc.html
#
# Top Jan. 6 Investigator Fired From Post at the University of Virginia
# Democrats in Virginia denounced the action as a partisan move aimed at helping former President Donald J. Trump undercut the investigation of the Capitol riot.
# https://www.nytimes.com/2022/01/23/us/politics/jan-6-investigator-fired-university-of-virginia.html
#
# Biden Weighs Deploying Thousands of Troops to Eastern Europe and Baltics
# The president is also considering deploying warships and aircraft to NATO allies, in what would be a major shift from its restrained stance on Ukraine.
# https://www.nytimes.com/2022/01/23/us/politics/biden-troops-nato-ukraine.html

# %%
# Enregistrement des articles_obam dans un fichier json

import json
with open('articles_obam.json', 'w') as f:
    json.dump(articles_obam, f)

# %%
print(dir(articles_obam[0]))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %% [markdown]
# # TRANSFORM

# %%
# Convertir les données en DataFrame pandas
import pandas as pd

articles_obam = pd.DataFrame(articles_obam)
articles_obam.head()
# Out:
#                                             abstract  \
# 0  The streaming service picks Joe Rogan over Nei...
# 1  With the backing of venture capital and well-k...
# 2  A conversation with the co-founder of Run for ...
# 3  Companies are wrestling with an array of state...
# 4  A return to a 2015 accord is on the table, but...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2022/02/01/opinion/spo...
# 1  https://www.nytimes.com/2022/02/01/business/al...
# 2  https://www.nytimes.com/2022/02/01/podcasts/tr...
# 3  https://www.nytimes.com/2022/02/01/business/de...
# 4  https://www.nytimes.com/2022/01/31/us/politics...
#
#                                              snippet  \
# 0  The streaming service picks Joe Rogan over Nei...
# 1  With the backing of venture capital and well-k...
# 2  A conversation with the co-founder of Run for ...
# 3  Companies are wrestling with an array of state...
# 4  A return to a 2015 accord is on the table, but...
#
#                                       lead_paragraph print_section print_page  \
# 0  The streaming service Spotify would like us to...            SR          6
# 1  In August 2017, Brian Wallach’s notion of time...             B          1
# 2  Every Tuesday and Friday, Ezra Klein invites y...           NaN        NaN
# 3  Now that the Biden administration’s nationwide...           NaN        NaN
# 4  WASHINGTON — The United States and its Europea...             A          8
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times                                                 []
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Spotify Backs Joe Rogan’s Disinforma...
# 1  {'main': 'A Race to Rethink Care After a Dire ...
# 2  {'main': 'Transcript: Ezra Klein Interviews Am...
# 3  {'main': 'States Are Complicating Corporate Pa...
# 4  {'main': 'U.S. and Allies Close to Reviving Nu...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Rogan, Joe', 'r...
# 1  [{'name': 'subject', 'value': 'Amyotrophic Lat...
# 2  [{'name': 'persons', 'value': 'Klein, Ezra', '...
# 3  [{'name': 'organizations', 'value': 'Carlyle G...
# 4  [{'name': 'subject', 'value': 'Nuclear Weapons...
#
#                    pub_date document_type   news_desk  section_name  \
# 0  2022-02-01T23:50:50+0000       article   Editorial       Opinion
# 1  2022-02-01T16:33:49+0000       article    Business  Business Day
# 2  2022-02-01T15:09:47+0000       article        OpEd      Podcasts
# 3  2022-02-01T12:33:37+0000       article    Business  Business Day
# 4  2022-02-01T00:27:13+0000       article  Washington          U.S.
#
#                                               byline type_of_material  \
# 0  {'original': 'By Greg Bensinger', 'person': [{...            Op-Ed
# 1  {'original': 'By Maureen Farrell', 'person': [...             News
# 2  {'original': None, 'person': [], 'organization...            Op-Ed
# 3  {'original': 'By Andrew Ross Sorkin, Jason Kar...             News
# 4  {'original': 'By David E. Sanger, Lara Jakes a...             News
#
#                                                  _id  word_count  \
# 0  nyt://article/a86e6e3c-7687-589a-b27a-6b570784...         957
# 1  nyt://article/d2a78924-19dc-551d-b2dd-665e27aa...        1375
# 2  nyt://article/94579bd5-6b92-5342-9fae-d2295bf8...       12451
# 3  nyt://article/b22a88ad-1ede-5a11-b043-fb42e13b...        1807
# 4  nyt://article/1f993990-0666-5f54-9de8-957abfcb...        1317
#
#                                                  uri subsection_name
# 0  nyt://article/a86e6e3c-7687-589a-b27a-6b570784...             NaN
# 1  nyt://article/d2a78924-19dc-551d-b2dd-665e27aa...             NaN
# 2  nyt://article/94579bd5-6b92-5342-9fae-d2295bf8...             NaN
# 3  nyt://article/b22a88ad-1ede-5a11-b043-fb42e13b...        DealBook
# 4  nyt://article/1f993990-0666-5f54-9de8-957abfcb...        Politics

# %% [markdown]
# ## Description de chaques colonnes du dataframe
# #### abstract : un résumé de l'article
# #### web_url : l'URL de l'article sur le site web du New York Times
# #### snippet : un court extrait de l'article
# #### lead_paragraph : le premier paragraphe de l'article
# #### source : la source de l'article
# #### multimedia : les médias associés à l'article (photos, vidéos, etc.)
# #### headline : le titre de l'article
# #### keywords : les mots-clés associés à l'article
# #### pub_date : la date de publication de l'article
# #### document_type : le type de document (généralement "article")
# #### news_desk : le domaine de couverture de l'article (par exemple "politique", "sports", etc.)
# #### section_name : la section de l'article sur le site web du New York Times
# #### subsection_name : la sous-section de l'article sur le site web du New York Times
# #### byline : l'auteur de l'article
# #### type_of_material : le type de contenu de l'article (par exemple "news", "opinion", etc.)
# #### _id : l'identifiant unique de l'article
# #### word_count : le nombre de mots dans l'article
# #### uri : l'URI de l'article
# #### print_section : la section de l'article dans la version imprimée du journal
# #### print_page : la page de l'article dans la version imprimée du journal
# #### sentiment : la polarité du sentiment de l'article (calculé à l'aide d'un modèle d'analyse de sentiment)

# %%
# compter le nombre de NAN dans chaque colonne

articles_obam.isnull().sum()
# Out:
# abstract             0
# web_url              0
# snippet              0
# lead_paragraph       0
# print_section       15
# print_page          15
# source               0
# multimedia           0
# headline             0
# keywords             0
# pub_date             0
# document_type        0
# news_desk            0
# section_name         0
# byline               0
# type_of_material     0
# _id                  0
# word_count           0
# uri                  0
# subsection_name     20
# dtype: int64

# %%
# Remplacement des NaN par une chaîne vide
articles_obam.fillna('', inplace=True)

# %%
articles_obam.head()
# Out:
#                                             abstract  \
# 0  The streaming service picks Joe Rogan over Nei...
# 1  With the backing of venture capital and well-k...
# 2  A conversation with the co-founder of Run for ...
# 3  Companies are wrestling with an array of state...
# 4  A return to a 2015 accord is on the table, but...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2022/02/01/opinion/spo...
# 1  https://www.nytimes.com/2022/02/01/business/al...
# 2  https://www.nytimes.com/2022/02/01/podcasts/tr...
# 3  https://www.nytimes.com/2022/02/01/business/de...
# 4  https://www.nytimes.com/2022/01/31/us/politics...
#
#                                              snippet  \
# 0  The streaming service picks Joe Rogan over Nei...
# 1  With the backing of venture capital and well-k...
# 2  A conversation with the co-founder of Run for ...
# 3  Companies are wrestling with an array of state...
# 4  A return to a 2015 accord is on the table, but...
#
#                                       lead_paragraph print_section print_page  \
# 0  The streaming service Spotify would like us to...            SR          6
# 1  In August 2017, Brian Wallach’s notion of time...             B          1
# 2  Every Tuesday and Friday, Ezra Klein invites y...
# 3  Now that the Biden administration’s nationwide...
# 4  WASHINGTON — The United States and its Europea...             A          8
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times                                                 []
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Spotify Backs Joe Rogan’s Disinforma...
# 1  {'main': 'A Race to Rethink Care After a Dire ...
# 2  {'main': 'Transcript: Ezra Klein Interviews Am...
# 3  {'main': 'States Are Complicating Corporate Pa...
# 4  {'main': 'U.S. and Allies Close to Reviving Nu...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Rogan, Joe', 'r...
# 1  [{'name': 'subject', 'value': 'Amyotrophic Lat...
# 2  [{'name': 'persons', 'value': 'Klein, Ezra', '...
# 3  [{'name': 'organizations', 'value': 'Carlyle G...
# 4  [{'name': 'subject', 'value': 'Nuclear Weapons...
#
#                    pub_date document_type   news_desk  section_name  \
# 0  2022-02-01T23:50:50+0000       article   Editorial       Opinion
# 1  2022-02-01T16:33:49+0000       article    Business  Business Day
# 2  2022-02-01T15:09:47+0000       article        OpEd      Podcasts
# 3  2022-02-01T12:33:37+0000       article    Business  Business Day
# 4  2022-02-01T00:27:13+0000       article  Washington          U.S.
#
#                                               byline type_of_material  \
# 0  {'original': 'By Greg Bensinger', 'person': [{...            Op-Ed
# 1  {'original': 'By Maureen Farrell', 'person': [...             News
# 2  {'original': None, 'person': [], 'organization...            Op-Ed
# 3  {'original': 'By Andrew Ross Sorkin, Jason Kar...             News
# 4  {'original': 'By David E. Sanger, Lara Jakes a...             News
#
#                                                  _id  word_count  \
# 0  nyt://article/a86e6e3c-7687-589a-b27a-6b570784...         957
# 1  nyt://article/d2a78924-19dc-551d-b2dd-665e27aa...        1375
# 2  nyt://article/94579bd5-6b92-5342-9fae-d2295bf8...       12451
# 3  nyt://article/b22a88ad-1ede-5a11-b043-fb42e13b...        1807
# 4  nyt://article/1f993990-0666-5f54-9de8-957abfcb...        1317
#
#                                                  uri subsection_name
# 0  nyt://article/a86e6e3c-7687-589a-b27a-6b570784...
# 1  nyt://article/d2a78924-19dc-551d-b2dd-665e27aa...
# 2  nyt://article/94579bd5-6b92-5342-9fae-d2295bf8...
# 3  nyt://article/b22a88ad-1ede-5a11-b043-fb42e13b...        DealBook
# 4  nyt://article/1f993990-0666-5f54-9de8-957abfcb...        Politics

# %%
# Compter à nouveau le nombre de NAN dans chaque colonne
articles_obam.isnull().sum()
# Out:
# abstract            0
# web_url             0
# snippet             0
# lead_paragraph      0
# print_section       0
# print_page          0
# source              0
# multimedia          0
# headline            0
# keywords            0
# pub_date            0
# document_type       0
# news_desk           0
# section_name        0
# byline              0
# type_of_material    0
# _id                 0
# word_count          0
# uri                 0
# subsection_name     0
# dtype: int64

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Liste des stopwords
stopwords = stopwords.words('english')
stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\NHOURA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Voir les colonnes inutiles du DataFrame dans l'analyse de sentiments
articles_obam.columns
# Out:
# Index(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section',
#        'print_page', 'source', 'multimedia', 'headline', 'keywords',
#        'pub_date', 'document_type', 'news_desk', 'section_name', 'byline',
#        'type_of_material', '_id', 'word_count', 'uri', 'subsection_name'],
#       dtype='object')

# %%
from textblob import TextBlob

def analyze_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

# %%
# Ajouter une colonne sentiment au DataFrame

articles_obam['sentiment'] = articles_obam['snippet'].apply(analyze_sentiment)
articles_obam.head()
# Out:
#                                             abstract  \
# 0  The streaming service picks Joe Rogan over Nei...
# 1  With the backing of venture capital and well-k...
# 2  A conversation with the co-founder of Run for ...
# 3  Companies are wrestling with an array of state...
# 4  A return to a 2015 accord is on the table, but...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2022/02/01/opinion/spo...
# 1  https://www.nytimes.com/2022/02/01/business/al...
# 2  https://www.nytimes.com/2022/02/01/podcasts/tr...
# 3  https://www.nytimes.com/2022/02/01/business/de...
# 4  https://www.nytimes.com/2022/01/31/us/politics...
#
#                                              snippet  \
# 0  The streaming service picks Joe Rogan over Nei...
# 1  With the backing of venture capital and well-k...
# 2  A conversation with the co-founder of Run for ...
# 3  Companies are wrestling with an array of state...
# 4  A return to a 2015 accord is on the table, but...
#
#                                       lead_paragraph print_section print_page  \
# 0  The streaming service Spotify would like us to...            SR          6
# 1  In August 2017, Brian Wallach’s notion of time...             B          1
# 2  Every Tuesday and Friday, Ezra Klein invites y...
# 3  Now that the Biden administration’s nationwide...
# 4  WASHINGTON — The United States and its Europea...             A          8
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times                                                 []
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Spotify Backs Joe Rogan’s Disinforma...
# 1  {'main': 'A Race to Rethink Care After a Dire ...
# 2  {'main': 'Transcript: Ezra Klein Interviews Am...
# 3  {'main': 'States Are Complicating Corporate Pa...
# 4  {'main': 'U.S. and Allies Close to Reviving Nu...
#
#                                             keywords  ... document_type  \
# 0  [{'name': 'persons', 'value': 'Rogan, Joe', 'r...  ...       article
# 1  [{'name': 'subject', 'value': 'Amyotrophic Lat...  ...       article
# 2  [{'name': 'persons', 'value': 'Klein, Ezra', '...  ...       article
# 3  [{'name': 'organizations', 'value': 'Carlyle G...  ...       article
# 4  [{'name': 'subject', 'value': 'Nuclear Weapons...  ...       article
#
#     news_desk  section_name  \
# 0   Editorial       Opinion
# 1    Business  Business Day
# 2        OpEd      Podcasts
# 3    Business  Business Day
# 4  Washington          U.S.
#
#                                               byline type_of_material  \
# 0  {'original': 'By Greg Bensinger', 'person': [{...            Op-Ed
# 1  {'original': 'By Maureen Farrell', 'person': [...             News
# 2  {'original': None, 'person': [], 'organization...            Op-Ed
# 3  {'original': 'By Andrew Ross Sorkin, Jason Kar...             News
# 4  {'original': 'By David E. Sanger, Lara Jakes a...             News
#
#                                                  _id word_count  \
# 0  nyt://article/a86e6e3c-7687-589a-b27a-6b570784...        957
# 1  nyt://article/d2a78924-19dc-551d-b2dd-665e27aa...       1375
# 2  nyt://article/94579bd5-6b92-5342-9fae-d2295bf8...      12451
# 3  nyt://article/b22a88ad-1ede-5a11-b043-fb42e13b...       1807
# 4  nyt://article/1f993990-0666-5f54-9de8-957abfcb...       1317
#
#                                                  uri subsection_name sentiment
# 0  nyt://article/a86e6e3c-7687-589a-b27a-6b570784...                  0.100000
# 1  nyt://article/d2a78924-19dc-551d-b2dd-665e27aa...                  0.000000
# 2  nyt://article/94579bd5-6b92-5342-9fae-d2295bf8...                  0.000000
# 3  nyt://article/b22a88ad-1ede-5a11-b043-fb42e13b...        DealBook  0.000000
# 4  nyt://article/1f993990-0666-5f54-9de8-957abfcb...        Politics  0.068182
#
# [5 rows x 21 columns]

# %%
#Fonction pour effectuer la partie tranformation des données du pipeline ETL

def transform_data(articles_obam):
    # Suppression des colonnes inutiles
    articles_obam.drop(['_id', 'document_type', 'multimedia', 'news_desk', 'print_page', 'print_section', 'section_name', 'snippet', 'type_of_material', 'word_count', 'subsection_name'], axis=1, inplace=True)

    # Renommage des colonnes
    articles_obam.rename(columns={'abstract': 'resume', 'headline.main': 'titre', 'pub_date': 'date', 'web_url': 'url'}, inplace=True)
    return articles_obam

# %%
articles_obam = transform_data(articles_obam)
articles_obam.head()
# Out:
#                                               resume  \
# 0  The streaming service picks Joe Rogan over Nei...
# 1  With the backing of venture capital and well-k...
# 2  A conversation with the co-founder of Run for ...
# 3  Companies are wrestling with an array of state...
# 4  A return to a 2015 accord is on the table, but...
#
#                                                  url  \
# 0  https://www.nytimes.com/2022/02/01/opinion/spo...
# 1  https://www.nytimes.com/2022/02/01/business/al...
# 2  https://www.nytimes.com/2022/02/01/podcasts/tr...
# 3  https://www.nytimes.com/2022/02/01/business/de...
# 4  https://www.nytimes.com/2022/01/31/us/politics...
#
#                                       lead_paragraph              source  \
# 0  The streaming service Spotify would like us to...  The New York Times
# 1  In August 2017, Brian Wallach’s notion of time...  The New York Times
# 2  Every Tuesday and Friday, Ezra Klein invites y...  The New York Times
# 3  Now that the Biden administration’s nationwide...  The New York Times
# 4  WASHINGTON — The United States and its Europea...  The New York Times
#
#                                             headline  \
# 0  {'main': 'Spotify Backs Joe Rogan’s Disinforma...
# 1  {'main': 'A Race to Rethink Care After a Dire ...
# 2  {'main': 'Transcript: Ezra Klein Interviews Am...
# 3  {'main': 'States Are Complicating Corporate Pa...
# 4  {'main': 'U.S. and Allies Close to Reviving Nu...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Rogan, Joe', 'r...
# 1  [{'name': 'subject', 'value': 'Amyotrophic Lat...
# 2  [{'name': 'persons', 'value': 'Klein, Ezra', '...
# 3  [{'name': 'organizations', 'value': 'Carlyle G...
# 4  [{'name': 'subject', 'value': 'Nuclear Weapons...
#
#                        date  \
# 0  2022-02-01T23:50:50+0000
# 1  2022-02-01T16:33:49+0000
# 2  2022-02-01T15:09:47+0000
# 3  2022-02-01T12:33:37+0000
# 4  2022-02-01T00:27:13+0000
#
#                                               byline  \
# 0  {'original': 'By Greg Bensinger', 'person': [{...
# 1  {'original': 'By Maureen Farrell', 'person': [...
# 2  {'original': None, 'person': [], 'organization...
# 3  {'original': 'By Andrew Ross Sorkin, Jason Kar...
# 4  {'original': 'By David E. Sanger, Lara Jakes a...
#
#                                                  uri  sentiment
# 0  nyt://article/a86e6e3c-7687-589a-b27a-6b570784...   0.100000
# 1  nyt://article/d2a78924-19dc-551d-b2dd-665e27aa...   0.000000
# 2  nyt://article/94579bd5-6b92-5342-9fae-d2295bf8...   0.000000
# 3  nyt://article/b22a88ad-1ede-5a11-b043-fb42e13b...   0.000000
# 4  nyt://article/1f993990-0666-5f54-9de8-957abfcb...   0.068182

# %% [markdown]
# # LOAD

# %%
# Fonction pour effectuer la partie chargement des données du pipeline ETL

def load_data(articles_obam):
    # Chargement du fichier articles_obam.csv
    articles_obam.to_csv('articles_obam.csv', index=False)

# %%
articles_obam = load_data(articles_obam)
articles_obam

# %% [markdown]
# # CREATION DE L'ARBORESCENCE DES FICHIERS

# %%
#Creation de l'aborescence des fichiers

import os
import shutil
import datetime

# chemin de base pour stocker les fichiers d'articles_obam
os.makedirs("Data_proj", exist_ok=True)
base_dir = "Data_proj"

# fonction pour déterminer le chemin de destination pour un fichier en fonction de sa date
def get_path_for_date(date):
    year = date.year
    month = date.month
    day = date.day
    return os.path.join(base_dir, str(year), str(month), str(day))

# boucle pour traiter chaque fichier d'article
for filename in os.listdir("Data_proj"):
    # supposer que le nom du fichier contient la date au format "YYYY-MM-DD"
    date_str = filename[:10]
    date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
    
    # déterminer le chemin de destination pour le fichier
    dest_path = get_path_for_date(date)
    
    # créer les dossiers nécessaires s'ils n'existent pas encore
    os.makedirs(dest_path, exist_ok=True)
    
    # déplacer le fichier dans le dossier approprié
    shutil.move(os.path.join("Data_proj", filename), dest_path)

# %% [markdown]
# # AIRFLOW

# %%
# %pip install apache-airflow
# Out:
# Collecting apache-airflow
#   Downloading apache_airflow-2.5.1-py3-none-any.whl (11.8 MB)
#      -------------------------------------- 11.8/11.8 MB 960.5 kB/s eta 0:00:00
# Collecting python-nvd3>=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting argcomplete>=1.10
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting cattrs>=22.1.0
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.8.2)
# Collecting apache-airflow-providers-imap
#   Downloading apache_airflow_providers_imap-3.1.1-py3-none-any.whl (17 kB)
# Collecting mdit-py-plugins>=0.3.0
#   Downloading mdit_py_plugins-0.3.4-py3-none-any.whl (52 kB)
#      -------------------------------------- 52.1/52.1 kB 243.2 kB/s eta 0:00:00
# Requirement already satisfied: psutil>=4.2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (5.9.0)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.5/79.5 kB 4.6 MB/s eta 0:00:00
# Collecting pendulum>=2.0
#   Downloading pendulum-2.1.2.tar.gz (81 kB)
#      -------------------------------------- 81.2/81.2 kB 909.3 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.1.1)
# Collecting croniter>=0.3.17
#   Downloading croniter-1.3.8-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=3.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.3.4)
# Collecting flask<2.3,>=2.2
#   Downloading Flask-2.2.3-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.8/101.8 kB 3.0 MB/s eta 0:00:00
# Collecting flask-caching>=1.5.0
#   Downloading Flask_Caching-2.0.2-py3-none-any.whl (28 kB)
# Collecting linkify-it-py>=2.0.0
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Collecting cron-descriptor>=1.2.24
#   Downloading cron_descriptor-1.2.35.tar.gz (29 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: blinker in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.5)
# Requirement already satisfied: pluggy>=1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.0.0)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.4.39)
# Collecting unicodecsv>=0.14.1
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting configupdater>=3.1.1
#   Downloading ConfigUpdater-3.1.1-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: dill>=0.2.2 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.3.6)
# Collecting flask-login>=0.6.2
#   Downloading Flask_Login-0.6.2-py3-none-any.whl (17 kB)
# Collecting apache-airflow-providers-common-sql
#   Downloading apache_airflow_providers_common_sql-1.3.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: packaging>=14.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (21.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.0.1)
# Collecting apache-airflow-providers-sqlite
#   Downloading apache_airflow_providers_sqlite-3.3.1-py3-none-any.whl (14 kB)
# Collecting flask-appbuilder==4.1.4
#   Downloading Flask_AppBuilder-4.1.4-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 1.1 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      -------------------------------------- 71.5/71.5 kB 785.0 kB/s eta 0:00:00
# Collecting setproctitle>=1.1.8
#   Downloading setproctitle-1.3.2-cp39-cp39-win_amd64.whl (11 kB)
# Requirement already satisfied: pathspec~=0.9.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (4.3.0)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.11.2)
# Collecting python-daemon>=2.2.4
#   Downloading python_daemon-2.3.2-py3-none-any.whl (34 kB)
# Collecting jinja2>=3.0.0
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting connexion[flask]>=2.10.0
#   Downloading connexion-2.14.2-py2.py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.1/95.1 kB 2.7 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.1.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.5/84.5 kB 4.6 MB/s eta 0:00:00
# Collecting colorlog<5.0,>=4.0.2
#   Downloading colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.0.1)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (5.0.2)
# Requirement already satisfied: rich>=12.4.4 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (12.6.0)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.8.10)
# Requirement already satisfied: graphviz>=0.12 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.20.1)
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-3.3.1-py3-none-any.whl (19 kB)
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Collecting flask-wtf>=0.15
#   Downloading Flask_WTF-1.1.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (8.0.1)
# Collecting sqlalchemy-jsonfield>=1.0
#   Downloading SQLAlchemy_JSONField-1.0.1.post0-py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (22.1.0)
# Collecting marshmallow-oneofschema>=2.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting flask-session>=0.4.0
#   Downloading Flask_Session-0.4.0-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: cryptography>=0.9.3 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (38.0.1)
# Requirement already satisfied: jsonschema>=3.2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (4.16.0)
# Requirement already satisfied: lazy-object-proxy in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.6.0)
# Requirement already satisfied: werkzeug>=2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.0.3)
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-4.2.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.4.0)
# Collecting alembic<2.0,>=1.6.3
#   Downloading alembic-1.9.4-py3-none-any.whl (210 kB)
#      -------------------------------------- 210.5/210.5 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.2.13)
# Collecting marshmallow<4,>=3
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.1/49.1 kB 2.4 MB/s eta 0:00:00
# Collecting marshmallow-sqlalchemy<0.27.0,>=0.22.0
#   Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl (15 kB)
# Collecting prison<1.0.0,>=0.2.1
#   Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: click<9,>=8 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (8.0.4)
# Collecting marshmallow-enum<2,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0
#   Downloading Flask_JWT_Extended-4.4.4-py2.py3-none-any.whl (22 kB)
# Collecting apispec[yaml]<4,>=3.3
#   Downloading apispec-3.3.2-py2.py3-none-any.whl (27 kB)
# Collecting WTForms<4
#   Downloading WTForms-3.0.1-py3-none-any.whl (136 kB)
#      -------------------------------------- 136.5/136.5 kB 4.1 MB/s eta 0:00:00
# Collecting Flask-Babel<3,>=1
#   Downloading Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.4.6)
# Collecting email-validator<2,>=1.0.5
#   Downloading email_validator-1.3.1-py2.py3-none-any.whl (22 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy_Utils-0.40.0-py3-none-any.whl (92 kB)
#      ---------------------------------------- 92.5/92.5 kB 5.1 MB/s eta 0:00:00
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.7/78.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in c:\users\nhoura\anaconda3\lib\site-packages (from cattrs>=22.1.0->apache-airflow) (1.1.0)
# Collecting clickclick<21,>=1.2
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: requests<3,>=2.9.1 in c:\users\nhoura\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow) (2.28.1)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\nhoura\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow) (0.5.1)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\nhoura\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow) (6.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\nhoura\anaconda3\lib\site-packages (from cryptography>=0.9.3->apache-airflow) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\nhoura\anaconda3\lib\site-packages (from deprecated>=1.2.13->apache-airflow) (1.14.1)
# Collecting werkzeug>=2.0
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      -------------------------------------- 233.6/233.6 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\nhoura\anaconda3\lib\site-packages (from flask<2.3,>=2.2->apache-airflow) (4.11.3)
# Collecting cachelib<0.10.0,>=0.9.0
#   Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools>=3.0 in c:\users\nhoura\anaconda3\lib\site-packages (from gunicorn>=20.1.0->apache-airflow) (65.5.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\nhoura\anaconda3\lib\site-packages (from jsonschema>=3.2.0->apache-airflow) (0.18.0)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nhoura\anaconda3\lib\site-packages (from packaging>=14.0->apache-airflow) (3.0.9)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      ------------------------------------ 490.0/490.0 kB 991.2 kB/s eta 0:00:00
# Requirement already satisfied: docutils in c:\users\nhoura\anaconda3\lib\site-packages (from python-daemon>=2.2.4->apache-airflow) (0.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\nhoura\anaconda3\lib\site-packages (from python-dateutil>=2.3->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\nhoura\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\nhoura\anaconda3\lib\site-packages (from rich>=12.4.4->apache-airflow) (0.9.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nhoura\anaconda3\lib\site-packages (from sqlalchemy<2.0,>=1.4->apache-airflow) (1.1.1)
# Collecting markupsafe>=1.1.1
#   Downloading MarkupSafe-2.1.2-cp39-cp39-win_amd64.whl (16 kB)
# Collecting sqlparse>=0.4.2
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB 2.0 MB/s eta 0:00:00
# Collecting asgiref
#   Downloading asgiref-3.6.0-py3-none-any.whl (23 kB)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (3.8.3)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in c:\users\nhoura\anaconda3\lib\site-packages (from httpx->apache-airflow) (1.2.0)
# Requirement already satisfied: certifi in c:\users\nhoura\anaconda3\lib\site-packages (from httpx->apache-airflow) (2022.9.24)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ---------------------------------------- 69.6/69.6 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in c:\users\nhoura\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow) (2.21)
# Requirement already satisfied: dnspython>=1.15.0 in c:\users\nhoura\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow) (2.2.1)
# Requirement already satisfied: idna>=2.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow) (3.4)
# Requirement already satisfied: pytz in c:\users\nhoura\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2022.1)
# Requirement already satisfied: Babel>=2.3 in c:\users\nhoura\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2.9.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\nhoura\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\nhoura\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\nhoura\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->flask<2.3,>=2.2->apache-airflow) (3.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nhoura\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nhoura\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.8.2)
# Building wheels for collected packages: cron-descriptor, pendulum, python-nvd3, unicodecsv
#   Building wheel for cron-descriptor (setup.py): started
#   Building wheel for cron-descriptor (setup.py): finished with status 'done'
#   Created wheel for cron-descriptor: filename=cron_descriptor-1.2.35-py3-none-any.whl size=48422 sha256=e1fa369cbc1bacc1507c9b1ab29a6a8b79ca0c3c592d90186dda7b3ede9644fc
#   Stored in directory: c:\users\nhoura\appdata\local\pip\cache\wheels\b6\c5\95\ecfd3eb95909eadd47c5ad25c8815c348d07bc248e12d3fd97
#   Building wheel for pendulum (pyproject.toml): started
#   Building wheel for pendulum (pyproject.toml): finished with status 'done'
#   Created wheel for pendulum: filename=pendulum-2.1.2-cp39-cp39-win_amd64.whl size=109765 sha256=6be6b028b62f3278b01d1e4cff5f133f336e4607feb4d5c6b6c113369f57ffe3
#   Stored in directory: c:\users\nhoura\appdata\local\pip\cache\wheels\c9\c7\29\3cf0033406b18958d1a7b107c38be2405ef9c081b64a264fd5
#   Building wheel for python-nvd3 (setup.py): started
#   Building wheel for python-nvd3 (setup.py): finished with status 'done'
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38149 sha256=693074643175f458be3ce5c61f080a6faeb7a981e36508277b1404cdaa085ec3
#   Stored in directory: c:\users\nhoura\appdata\local\pip\cache\wheels\60\e8\21\19a3dcfe90e8895952857d42152663fafc5a90d87d3dfe5f58
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10746 sha256=f6fc6fd768bc88390d81796fa8e34be02220de872ae6c2a7f821b9a78af07e4d
#   Stored in directory: c:\users\nhoura\appdata\local\pip\cache\wheels\d8\c8\27\b237d3378d5c9ed25c2c63d9af1b3d5ccb99934f3dd030de87
# Successfully built cron-descriptor pendulum python-nvd3 unicodecsv
# Installing collected packages: unicodecsv, rfc3986, lockfile, cron-descriptor, uc-micro-py, sqlparse, setproctitle, pytzdata, python-daemon, prison, mdurl, markupsafe, gunicorn, email-validator, configupdater, colorlog, cattrs, cachelib, asgiref, argcomplete, apispec, apache-airflow-providers-imap, apache-airflow-providers-ftp, WTForms, werkzeug, sqlalchemy-utils, sqlalchemy-jsonfield, requests-toolbelt, pendulum, marshmallow, markdown-it-py, Mako, linkify-it-py, jinja2, httpcore, croniter, clickclick, apache-airflow-providers-common-sql, python-nvd3, mdit-py-plugins, marshmallow-sqlalchemy, marshmallow-oneofschema, marshmallow-enum, httpx, flask, apache-airflow-providers-sqlite, apache-airflow-providers-http, alembic, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-JWT-Extended, flask-caching, Flask-Babel, connexion, flask-appbuilder, apache-airflow
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.2
#     Uninstalling Flask-1.1.2:
#       Successfully uninstalled Flask-1.1.2
# Successfully installed Flask-Babel-2.0.0 Flask-JWT-Extended-4.4.4 Flask-SQLAlchemy-2.5.1 Mako-1.2.4 WTForms-3.0.1 alembic-1.9.4 apache-airflow-2.5.1 apache-airflow-providers-common-sql-1.3.3 apache-airflow-providers-ftp-3.3.1 apache-airflow-providers-http-4.2.0 apache-airflow-providers-imap-3.1.1 apache-airflow-providers-sqlite-3.3.1 apispec-3.3.2 argcomplete-2.0.0 asgiref-3.6.0 cachelib-0.9.0 cattrs-22.2.0 clickclick-20.10.2 colorlog-4.8.0 configupdater-3.1.1 connexion-2.14.2 cron-descriptor-1.2.35 croniter-1.3.8 email-validator-1.3.1 flask-2.2.3 flask-appbuilder-4.1.4 flask-caching-2.0.2 flask-login-0.6.2 flask-session-0.4.0 flask-wtf-1.1.1 gunicorn-20.1.0 httpcore-0.16.3 httpx-0.23.3 jinja2-3.1.2 linkify-it-py-2.0.0 lockfile-0.12.2 markdown-it-py-2.2.0 markupsafe-2.1.2 marshmallow-3.19.0 marshmallow-enum-1.5.1 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.26.1 mdit-py-plugins-0.3.4 mdurl-0.1.2 pendulum-2.1.2 prison-0.2.1 python-daemon-2.3.2 python-nvd3-0.15.0 pytzdata-2020.1 requests-toolbelt-0.10.1 rfc3986-1.5.0 setproctitle-1.3.2 sqlalchemy-jsonfield-1.0.1.post0 sqlalchemy-utils-0.40.0 sqlparse-0.4.3 uc-micro-py-1.0.1 unicodecsv-0.14.1 werkzeug-2.2.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script sqlformat.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script gunicorn.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script email_validator.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mako-render.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nvd3.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script flask.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script connexion.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fabmanager.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script airflow.exe is installed in 'c:\Users\NHOURA\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.

# %%
# %pip install ruamel-yaml
# Out:
# Collecting ruamel-yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ------------------------------------ 109.5/109.5 kB 530.7 kB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp39-cp39-win_amd64.whl (118 kB)
#      -------------------------------------- 118.4/118.4 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel-yaml
# Successfully installed ruamel-yaml-0.17.21 ruamel.yaml.clib-0.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install apache-airflow
# Out:
# Requirement already satisfied: apache-airflow in c:\users\nhoura\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.1.2)
# Requirement already satisfied: blinker in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.5)
# Requirement already satisfied: apache-airflow-providers-imap in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.1.1)
# Requirement already satisfied: flask-caching>=1.5.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.0.2)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.0.0)
# Requirement already satisfied: flask-session>=0.4.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.4.0)
# Requirement already satisfied: python-daemon>=2.2.4 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.3.2)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (5.0.2)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.12.2)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.1.2)
# Requirement already satisfied: apache-airflow-providers-http in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (4.2.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.0.1)
# Requirement already satisfied: apache-airflow-providers-ftp in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.3.1)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.0.0)
# Requirement already satisfied: setproctitle>=1.1.8 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.3.2)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.2.13)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.2.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (20.1.0)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.2.35)
# Requirement already satisfied: dill>=0.2.2 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.3.6)
# Requirement already satisfied: connexion[flask]>=2.10.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.14.2)
# Requirement already satisfied: python-nvd3>=0.15.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.15.0)
# Requirement already satisfied: rich>=12.4.4 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (12.6.0)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.4.0)
# Requirement already satisfied: flask-login>=0.6.2 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.6.2)
# Requirement already satisfied: graphviz>=0.12 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.20.1)
# Requirement already satisfied: jsonschema>=3.2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (4.16.0)
# Requirement already satisfied: configupdater>=3.1.1 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.1.1)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.8.10)
# Requirement already satisfied: flask-wtf>=0.15 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.1.1)
# Requirement already satisfied: pluggy>=1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (8.0.1)
# Requirement already satisfied: werkzeug>=2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.2.3)
# Requirement already satisfied: cryptography>=0.9.3 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (38.0.1)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.0.1.post0)
# Requirement already satisfied: pendulum>=2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.1.2)
# Requirement already satisfied: apache-airflow-providers-sqlite in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.3.1)
# Requirement already satisfied: packaging>=14.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (21.3)
# Requirement already satisfied: pathspec~=0.9.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.9.0)
# Requirement already satisfied: psutil>=4.2.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (5.9.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.14.1)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (22.1.0)
# Requirement already satisfied: flask<2.3,>=2.2 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.2.3)
# Requirement already satisfied: markdown>=3.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (3.3.4)
# Requirement already satisfied: colorlog<5.0,>=4.0.2 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (4.8.0)
# Requirement already satisfied: flask-appbuilder==4.1.4 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (4.1.4)
# Requirement already satisfied: lazy-object-proxy in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.6.0)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.4.39)
# Requirement already satisfied: alembic<2.0,>=1.6.3 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.9.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (4.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.1.1)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.3.4)
# Requirement already satisfied: croniter>=0.3.17 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.3.8)
# Requirement already satisfied: httpx in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (0.23.3)
# Requirement already satisfied: cattrs>=22.1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (22.2.0)
# Requirement already satisfied: apache-airflow-providers-common-sql in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.8.2)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow) (2.11.2)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.4.6)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.2.1)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.40.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (2.5.1)
# Requirement already satisfied: click<9,>=8 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (8.0.4)
# Requirement already satisfied: WTForms<4 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (3.0.1)
# Requirement already satisfied: marshmallow<4,>=3 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (3.19.0)
# Requirement already satisfied: Flask-Babel<3,>=1 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (2.0.0)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (4.4.4)
# Requirement already satisfied: apispec[yaml]<4,>=3.3 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (3.3.2)
# Requirement already satisfied: marshmallow-sqlalchemy<0.27.0,>=0.22.0 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (0.26.1)
# Requirement already satisfied: marshmallow-enum<2,>=1.5.1 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (1.5.1)
# Requirement already satisfied: email-validator<2,>=1.0.5 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow) (1.3.1)
# Requirement already satisfied: Mako in c:\users\nhoura\anaconda3\lib\site-packages (from alembic<2.0,>=1.6.3->apache-airflow) (1.2.4)
# Requirement already satisfied: exceptiongroup in c:\users\nhoura\anaconda3\lib\site-packages (from cattrs>=22.1.0->apache-airflow) (1.1.0)
# Requirement already satisfied: clickclick<21,>=1.2 in c:\users\nhoura\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow) (20.10.2)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\nhoura\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow) (0.5.1)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\nhoura\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow) (6.0)
# Requirement already satisfied: requests<3,>=2.9.1 in c:\users\nhoura\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow) (2.28.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\nhoura\anaconda3\lib\site-packages (from cryptography>=0.9.3->apache-airflow) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\nhoura\anaconda3\lib\site-packages (from deprecated>=1.2.13->apache-airflow) (1.14.1)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\nhoura\anaconda3\lib\site-packages (from flask<2.3,>=2.2->apache-airflow) (4.11.3)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in c:\users\nhoura\anaconda3\lib\site-packages (from flask-caching>=1.5.0->apache-airflow) (0.9.0)
# Requirement already satisfied: setuptools>=3.0 in c:\users\nhoura\anaconda3\lib\site-packages (from gunicorn>=20.1.0->apache-airflow) (65.5.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\nhoura\anaconda3\lib\site-packages (from jsonschema>=3.2.0->apache-airflow) (0.18.0)
# Requirement already satisfied: uc-micro-py in c:\users\nhoura\anaconda3\lib\site-packages (from linkify-it-py>=2.0.0->apache-airflow) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nhoura\anaconda3\lib\site-packages (from markdown-it-py>=2.1.0->apache-airflow) (0.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nhoura\anaconda3\lib\site-packages (from packaging>=14.0->apache-airflow) (3.0.9)
# Requirement already satisfied: pytzdata>=2020.1 in c:\users\nhoura\anaconda3\lib\site-packages (from pendulum>=2.0->apache-airflow) (2020.1)
# Requirement already satisfied: docutils in c:\users\nhoura\anaconda3\lib\site-packages (from python-daemon>=2.2.4->apache-airflow) (0.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\nhoura\anaconda3\lib\site-packages (from python-dateutil>=2.3->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\nhoura\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\nhoura\anaconda3\lib\site-packages (from rich>=12.4.4->apache-airflow) (0.9.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nhoura\anaconda3\lib\site-packages (from sqlalchemy<2.0,>=1.4->apache-airflow) (1.1.1)
# Requirement already satisfied: sqlparse>=0.4.2 in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow) (0.4.3)
# Requirement already satisfied: asgiref in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (3.6.0)
# Requirement already satisfied: aiohttp in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (3.8.3)
# Requirement already satisfied: requests-toolbelt in c:\users\nhoura\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (0.10.1)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\nhoura\anaconda3\lib\site-packages (from httpx->apache-airflow) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\nhoura\anaconda3\lib\site-packages (from httpx->apache-airflow) (0.16.3)
# Requirement already satisfied: certifi in c:\users\nhoura\anaconda3\lib\site-packages (from httpx->apache-airflow) (2022.9.24)
# Requirement already satisfied: sniffio in c:\users\nhoura\anaconda3\lib\site-packages (from httpx->apache-airflow) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\nhoura\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow) (2.21)
# Requirement already satisfied: dnspython>=1.15.0 in c:\users\nhoura\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow) (2.2.1)
# Requirement already satisfied: idna>=2.0.0 in c:\users\nhoura\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow) (3.4)
# Requirement already satisfied: pytz in c:\users\nhoura\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2022.1)
# Requirement already satisfied: Babel>=2.3 in c:\users\nhoura\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2.9.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\nhoura\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (3.5.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\nhoura\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\nhoura\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->flask<2.3,>=2.2->apache-airflow) (3.8.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nhoura\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nhoura\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow) (1.26.12)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nhoura\anaconda3\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow) (6.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importation des librairies
import airflow
from airflow import DAG
from airflow.operators.python_operator import PythonOperator
from airflow.operators.bash_operator import BashOperator
from datetime import datetime, timedelta

# Définition des arguments du DAG
args = {
    'owner': 'airflow',
    'start_date': airflow.utils.dates.days_ago(2),
    'depends_on_past': False,
    'email': [''],
    'email_on_failure': False,
    'email_on_retry': False,
    'retries': 1,
    'retry_delay': timedelta(minutes=5),
}

# Définition du DAG
dag = DAG(
    dag_id='articles_obam',
    default_args=args,
    description='Extraction, transformation et chargement des articles_obam',
    schedule_interval=timedelta(days=1),
)

# Définition des tâches
t1 = BashOperator(
    task_id='extract_data',
    bash_command='python3 extract_data.py',
    dag=dag,
)

t2 = BashOperator(
    task_id='transform_data',
    bash_command='python3 transform_data.py',
    dag=dag,
)

t3 = BashOperator(
    task_id='load_data',
    bash_command='python3 load_data.py',
    dag=dag,
)

# Définition des dépendances
t1 >> t2 >> t3

# Lancement du DAG
dag.cli()

# Lancement du serveur web
airflow webserver -p 8080

# Lancement du scheduler
airflow scheduler
# Out:
#   File "C:\Users\NHOURA\AppData\Local\Temp\ipykernel_23836\706620132.py", line 1
#     airflow initdb
#             ^
# SyntaxError: invalid syntax

# %%
from airflow import DAG
from airflow.operators.bash_operator import BashOperator
from datetime import datetime, timedelta

default_args = {
    'owner': 'airflow',
    'depends_on_past': False,
    'start_date': datetime(2022, 2, 1),
    'email': ['airflow@example.com'],
    'email_on_failure': False,
    'email_on_retry': False,
    'retries': 1,
    'retry_delay': timedelta(minutes=5),
}

dag = DAG(
    'my_dag',
    default_args=default_args,
    schedule_interval='7 16 * * *',
)

task = BashOperator(
    task_id='my_task',
    bash_command='echo "Hello world"',
    dag=dag,
)

# %% [markdown]
# Jenkins est un outil idéal pour l'automatisation de tâches linéaires et pour l'intégration continue, tandis qu'Airflow est plus adapté pour la gestion de flux de travail complexes, avec des dépendances et des tâches qui doivent s'exécuter dans un ordre précis.
